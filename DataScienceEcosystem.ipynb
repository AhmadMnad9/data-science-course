# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# #### Some of the popular languages that Data Scientists use are:
# 1. python
# 2. R
# 3. SQL
# 4. Julia
# 5. Java
# 6. Matlab

# %% [markdown]
# #### Some of the commonly used libraries used by Data Scientists include:
# |  Python       |       R       |
# |---------------|---------------|
# |pandas         |dplyr , tidyverse   |
# |matplotlib , seaborn     |ggplot2    |
# |scikit-learn      |mlr , randomForest    |
# |tenserflow, keras, pytorch  |keras, RSNNS          |
# |sqlite3       |DBI , RMySQL              |

# %% [markdown]
# #### Data Science Tools
# 1. Google Colab
# 2. Anaconda
# 3. Excel
# 4. Tableau
# 5. MLflow
# 6. Git
# 7. Docker

# %% [markdown]
# #### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This a simple arithmetic expression to mutiply then add integers
x = 3
y = 4
z = 5
ans = (x*y)+z
print(ans)
# Out:
# 17

# %%
#  This will convert 200 minutes to hours by diving by 60
min = 200
hour = min/60
print(hour)
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
#
# - List the most commonly used programming languages in Data Science
# - Identify popular libraries for Python and R used in Data Science workflows
# - Describe essential tools used by Data Scientists to work with data efficiently
# - Perform basic operations using Python, including working with variables

# %% [markdown]
# ## Author
# Ahmad Mnadili
